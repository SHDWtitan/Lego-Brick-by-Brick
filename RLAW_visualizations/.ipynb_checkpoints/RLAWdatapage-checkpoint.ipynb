# %%
import numpy as np
import pandas as pd
import matplotlib as mplt
import seaborn as sns
import matplotlib.pyplot as plt
import json
import csv
import altair as alt

# %%
with open ('average_pieces_per_theme.vl.json', 'r', encoding = 'utf-8') as chart_1:
    chart_1_data = json.load(chart_1)

with open ('max_pieces_per_theme.vl.json', 'r', encoding = 'utf-8') as chart_2:
    chart_2_data = json.load(chart_2)

with open ('sets_with_pieces_over_2k_by_year.vl.json', 'r', encoding = 'utf-8') as chart_3:
    chart_3_data = json.load(chart_3)

# %%
alt.Chart.from_dict(chart_1_data)
# Out:
# alt.Chart(...)

# %%
alt.Chart.from_dict(chart_2_data)
# Out:
# alt.Chart(...)

# %%
alt.Chart.from_dict(chart_3_data)
# Out:
# alt.Chart(...)
